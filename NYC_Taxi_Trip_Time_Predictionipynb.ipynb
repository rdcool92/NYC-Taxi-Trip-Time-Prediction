# %% [markdown]
# <a href="https://colab.research.google.com/github/rdcool92/NYC-Taxi-Trip-Time-Prediction/blob/main/NYC_Taxi_Trip_Time_Predictionipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - Regression
# ##### **Team Member 1 -** Mukesh Kumar Yadav
# ##### **Team Member 2 -** Rahul Dev
# ##### **Team Member 3 -** Sangita Kumari

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The project objective is to predict total trip duration of a taxi in Newyork City. We are provided dataset from AlmaBetter whcih has been used in this project for developing a Machine learning model. The dataset contains deatils about pick up location and time, drop off location and time, no. of passengers and taxi service provider type. If all thses deatils are known then we would be able to predict trip duration using thses details.
#
# **The project follows following steps:**
#
# **Step 1.** Loading data and getting statistics <br>
# **step 2.** Handling Null values/ Missing values and removing duplicate observations<br>
# **Step 3.** Now our data is cleaned and ready for visualization and getting insights from different charts such as:<br>
#    1. Bar plot
#    2. Distribution plot
#    3. Box plots
#    4. Hist plots
#    5. Line plots
#    6. Double bar plots
#    7. stacked bar plots
#    8. Confusion matrix
#    9. Pie charts <br>
#
# **step 4.** From boxplots and distribution plots we get to know about outliers and we remove outliers in this step usingv IQR and value capping using normal distribution.<br>
# **Step 5.** We created two feature under Feature Engineerig and we also used feature encoding for categorical variables.<br>
# **Step 6.** We used Standard Scaler for scaling features and then trained models with default hyperparameters.<br>
# **Step 7.** Then selected algorithm with higest r2 score and fine tuned hyperparameter for that algorithm. finally our model is ready for predictions.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Your task is to build a model that predicts the total ride duration of taxi trips in New York City. Your primary dataset is one released by the NYC Taxi and Limousine Commission, which includes pickup time, geo-coordinates, number of passengers, and several other variables

# %% [markdown]
# # ***Let's Begin !***

# %%
# mounting drive to colab notebook
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# loading required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# %%
# reading data and creatinf DataFrame
data=pd.read_csv('/content/drive/MyDrive/NYC Taxi Data.csv')

# %% [markdown]
# ## ***1. Know Your Data***

# %%
# get data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458644 entries, 0 to 1458643
# Data columns (total 11 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id                  1458644 non-null  object
#  1   vendor_id           1458644 non-null  int64
#  2   pickup_datetime     1458644 non-null  object
#  3   dropoff_datetime    1458644 non-null  object
#  4   passenger_count     1458644 non-null  int64
#  5   pickup_longitude    1458644 non-null  float64
#  6   pickup_latitude     1458644 non-null  float64
#  7   dropoff_longitude   1458644 non-null  float64
#  8   dropoff_latitude    1458644 non-null  float64
#  9   store_and_fwd_flag  1458644 non-null  object
#  10  trip_duration       1458644 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 122.4+ MB

# %% [markdown]
# This dataset contains 14,58,644 observations and 11 columns
# We observe that the pickup_datetime and dropoff_datetime is in object type, There it is needed to convert to datetime data type

# %%
# top 5 observations
data.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.765602                  N            455
# 1         40.731152                  N            663
# 2         40.710087                  N           2124
# 3         40.706718                  N            429
# 4         40.782520                  N            435

# %%
# bottom 5 observations
data.tail()
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 1458639  id2376096          2  2016-04-08 13:31:04  2016-04-08 13:44:02
# 1458640  id1049543          1  2016-01-10 07:35:15  2016-01-10 07:46:10
# 1458641  id2304944          2  2016-04-22 06:57:41  2016-04-22 07:10:25
# 1458642  id2714485          1  2016-01-05 15:56:26  2016-01-05 16:02:39
# 1458643  id1209952          1  2016-04-05 14:44:25  2016-04-05 14:47:43
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 1458639                4        -73.982201        40.745522
# 1458640                1        -74.000946        40.747379
# 1458641                1        -73.959129        40.768799
# 1458642                1        -73.982079        40.749062
# 1458643                1        -73.979538        40.781750
#
#          dropoff_longitude  dropoff_latitude store_and_fwd_flag  trip_duration
# 1458639         -73.994911         40.740170                  N            778
# 1458640         -73.970184         40.796547                  N            655
# 1458641         -74.004433         40.707371                  N            764
# 1458642         -73.974632         40.757107                  N            373
# 1458643         -73.972809         40.790585                  N            198

# %% [markdown]
# id is unique for each trip so this column has no effect on trip duration prediction, Therefore it is better to drop this column.

# %%
# check null values
data.isnull().sum()
# Out:
# id                    0
# vendor_id             0
# pickup_datetime       0
# dropoff_datetime      0
# passenger_count       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# store_and_fwd_flag    0
# trip_duration         0
# dtype: int64

# %% [markdown]
# The dataset contains no null values

# %%
# check duplicates values
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# This dataset contains no duplicated values

# %%
# get statistics of numerical columns
data.describe().T
# Out:
#                        count        mean          std         min         25%  \
# vendor_id          1458644.0    1.534950     0.498777    1.000000    1.000000
# passenger_count    1458644.0    1.664530     1.314242    0.000000    1.000000
# pickup_longitude   1458644.0  -73.973486     0.070902 -121.933342  -73.991867
# pickup_latitude    1458644.0   40.750921     0.032881   34.359695   40.737347
# dropoff_longitude  1458644.0  -73.973416     0.070643 -121.933304  -73.991325
# dropoff_latitude   1458644.0   40.751800     0.035891   32.181141   40.735885
# trip_duration      1458644.0  959.492273  5237.431724    1.000000  397.000000
#
#                           50%          75%           max
# vendor_id            2.000000     2.000000  2.000000e+00
# passenger_count      1.000000     2.000000  9.000000e+00
# pickup_longitude   -73.981743   -73.967331 -6.133553e+01
# pickup_latitude     40.754101    40.768360  5.188108e+01
# dropoff_longitude  -73.979752   -73.963013 -6.133553e+01
# dropoff_latitude    40.754524    40.769810  4.392103e+01
# trip_duration      662.000000  1075.000000  3.526282e+06

# %%
# get statistics of non-numeric columns
data.describe(include='O').T
# Out:
#                       count   unique                  top     freq
# id                  1458644  1458644            id2875421        1
# pickup_datetime     1458644  1380222  2016-03-04 08:07:34        5
# dropoff_datetime    1458644  1380377  2016-02-19 19:25:04        5
# store_and_fwd_flag  1458644        2                    N  1450599

# %%
# drop id column
data.drop(['id'], axis=1, inplace=True)
data.head(3)
# Out:
#    vendor_id      pickup_datetime     dropoff_datetime  passenger_count  \
# 0          2  2016-03-14 17:24:55  2016-03-14 17:32:30                1
# 1          1  2016-06-12 00:43:35  2016-06-12 00:54:38                1
# 2          2  2016-01-19 11:35:24  2016-01-19 12:10:48                1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.982155        40.767937         -73.964630         40.765602
# 1        -73.980415        40.738564         -73.999481         40.731152
# 2        -73.979027        40.763939         -74.005333         40.710087
#
#   store_and_fwd_flag  trip_duration
# 0                  N            455
# 1                  N            663
# 2                  N           2124

# %% [markdown]
# ## **2.Data visulation**

# %% [markdown]
# ###Chart-1

# %%
def without_hue(ax, feature):

  '''To add percentage on top of bar plot drawn by seaborn '''
  
  total = len(feature)
  for p in ax.patches:
      percentage = '{:.1f}%'.format(100 * p.get_height()/total)
      x = p.get_x() + p.get_width() / 2 - 0.05
      y = p.get_y() + p.get_height()
      ax.annotate(percentage, (x, y), size = 12)

# %%
#bar plot
ax=sns.countplot(data=data, x='vendor_id')
plt.xlabel('Vendor ID')
plt.ylabel('No of Trips')
without_hue(ax, data.vendor_id)

# %% [markdown]
# The above bar plot shows that Vendor 2 has got 7% more taxi trips than vendor 1.The difference is not much but it can help find why vendor 1 trips are low?
#
# The numbers of taxi trip services provided by both service providers are almost same and equals to 50%

# %% [markdown]
# ### Chart-2

# %%
# bar plot of counts
ax=sns.countplot(data=data, x='passenger_count')
plt.xlabel('No. of Passengers')
plt.ylabel('No of Trips')
# Out:
# Text(0, 0.5, 'No of Trips')

# %% [markdown]
# Most taxi trips carry one passengers and they rarely carry zero passengers or more than six.

# %% [markdown]
# ### Chart-3

# %%
# bar plot
ax=sns.countplot(data=data, x='store_and_fwd_flag')
plt.xlabel('Trip Records Stored in Vehicle ')
plt.ylabel('No of Trips')
# Out:
# Text(0, 0.5, 'No of Trips')

# %% [markdown]
# Most of the trip records are held in vehicle memory.

# %% [markdown]
# ### Chart-4

# %% [markdown]
# As plotiing location denstity plot off all location can be comutational expensive do taking 10,000 samples and ploting it.

# %%
"""import plotly.express as px

# Create a DataFrame with columns 'lat' and 'lon'
data = pd.DataFrame({
    'lat': lat[:1000000],
    'lon': lon[:1000000]
})

# Create a density map
fig = px.density_mapbox(data, lat='lat', lon='lon', radius=10, zoom=10,
                        mapbox_style="carto-positron", opacity=0.8)
# , width=10, height=10
fig.update_layout(title='Density of Pick Up Locations', width=1500, height=800)
fig.show()"""

# %%
# geographical plot
lat=data.sample(n=10000, random_state=42)['dropoff_latitude'].tolist()
lon=data.sample(n=10000, random_state=42)['dropoff_longitude'].tolist()
import plotly.express as px

# Create a DataFrame with columns 'lat' and 'lon'
data_ = pd.DataFrame({
    'lat': lat,
    'lon': lon
})

# Create a density map
fig = px.density_mapbox(data_, lat='lat', lon='lon', radius=10, zoom=10,
                        mapbox_style="carto-positron", opacity=0.8)
# , width=10, height=10
fig.update_layout(title='Density of Drop Off Locations', width=1500, height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="74115cd3-bded-4147-99a4-fec6ad69e4e7" class="plotly-graph-div" style="height:800px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74115cd3-bded-4147-99a4-fec6ad69e4e7")) {                    Plotly.newPlot(                        "74115cd3-bded-4147-99a4-fec6ad69e4e7",                        [{"coloraxis":"coloraxis","hovertemplate":"lat=%{lat}<br>lon=%{lon}<extra></extra>","lat":[40.76046752929688,40.749858856201165,40.74869155883789,40.74891662597656,40.759231567382805,40.767181396484375,40.78289031982422,40.75593185424805,40.71656036376953,40.858222961425774,40.74044036865234,40.754497528076165,40.75481033325195,40.723411560058594,40.763328552246094,40.75846862792969,40.64407730102539,40.71902084350586,40.76401519775391,40.666061401367195,40.73117065429688,40.795989990234375,40.80934524536133,40.74674987792969,40.785640716552734,40.74813079833984,40.7563362121582,40.7605857849121,40.7519416809082,40.748634338378906,40.718406677246094,40.74605178833008,40.76372909545898,40.77972030639648,40.80934143066406,40.75618743896485,40.709999084472656,40.72031021118164,40.757118225097656,40.75537872314453,40.78142929077149,40.73429870605469,40.734493255615234,40.76960754394531,40.75584411621094,40.709522247314446,40.71686172485352,40.75875473022461,40.77730941772461,40.75081253051758,40.7086181640625,40.76082611083984,40.768821716308594,40.72303009033203,40.752826690673835,40.78346633911133,40.79264068603516,40.729995727539055,40.7623176574707,40.72901153564453,40.79563903808594,40.76021194458008,40.7985954284668,40.73099136352539,40.77720642089844,40.7256088256836,40.7423210144043,40.741565704345696,40.7415885925293,40.71302032470703,40.76758193969727,40.74039077758789,40.804718017578125,40.78281021118164,40.73927688598633,40.75807189941406,40.765789031982415,40.72564315795898,40.7629508972168,40.75115203857422,40.738384246826165,40.74045944213867,40.75157928466797,40.77357482910156,40.76444625854492,40.79384994506836,40.70955657958984,40.75715637207031,40.73417663574219,40.768211364746094,40.64337158203125,40.7657470703125,40.712940216064446,40.72216033935546,40.766498565673835,40.75891876220703,40.76790618896485,40.76818084716797,40.74200820922852,40.75450897216797,40.74715423583984,40.7335090637207,40.71994400024414,40.72730255126953,40.75208282470703,40.745113372802734,40.70585250854492,40.77922058105469,40.77010726928711,40.74496841430664,40.66501235961913,40.75376892089844,40.74129486083984,40.745960235595696,40.78485107421875,40.77404022216797,40.7894401550293,40.78208160400391,40.72673797607422,40.783203125,40.75052261352539,40.75502395629882,40.76984024047852,40.74396133422852,40.77825927734375,40.746341705322266,40.74087905883789,40.692378997802734,40.73469161987305,40.67066955566406,40.77444839477539,40.77068328857422,40.763042449951165,40.76058197021485,40.75933456420898,40.694068908691406,40.759559631347656,40.74554443359375,40.772075653076165,40.747859954833984,40.805370330810554,40.727500915527344,40.81761932373047,40.709487915039055,40.754253387451165,40.79875183105469,40.76875686645508,40.74052429199219,40.74008560180664,40.750301361083984,40.72715759277344,40.73912811279297,40.7509994506836,40.775981903076165,40.70644760131836,40.75755310058594,40.7374153137207,40.81399154663086,40.71199035644531,40.73306274414063,40.771183013916016,40.730178833007805,40.75920104980469,40.70397186279297,40.7087516784668,40.758834838867195,40.73122787475586,40.77019119262695,40.78799057006836,40.755950927734375,40.76082611083984,40.784446716308594,40.72298049926758,40.77585220336913,40.71470642089844,40.74414825439453,40.750606536865234,40.748321533203125,40.80873107910156,40.601165771484375,40.73046875,40.7590446472168,40.734962463378906,40.73469924926758,40.68962860107422,40.78278 ...

# %% [markdown]
# ### Chart-5

# %%
# geographical plot
lat=data.sample(n=10000, random_state=42)['pickup_latitude'].tolist()
lon=data.sample(n=10000, random_state=42)['pickup_longitude'].tolist()
import plotly.express as px

# Create a DataFrame with columns 'lat' and 'lon'
data_ = pd.DataFrame({
    'lat': lat,
    'lon': lon
})

# Create a density map
fig = px.density_mapbox(data_, lat='lat', lon='lon', radius=10, zoom=10,
                        mapbox_style="carto-positron", opacity=0.8)
# , width=10, height=10
fig.update_layout(title='Density of Pick Up Locations', width=1500, height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="df07667f-2e1d-4518-a204-5d0b63bf8f6c" class="plotly-graph-div" style="height:800px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df07667f-2e1d-4518-a204-5d0b63bf8f6c")) {                    Plotly.newPlot(                        "df07667f-2e1d-4518-a204-5d0b63bf8f6c",                        [{"coloraxis":"coloraxis","hovertemplate":"lat=%{lat}<br>lon=%{lon}<extra></extra>","lat":[40.735942840576165,40.76435089111328,40.744388580322266,40.73113632202149,40.64667510986328,40.768569946289055,40.76000595092773,40.74969482421875,40.764461517333984,40.79482650756836,40.71452331542969,40.74713516235352,40.64543151855469,40.743701934814446,40.7881965637207,40.75626373291016,40.762977600097656,40.73118209838867,40.74526977539063,40.71453857421875,40.74928665161133,40.74649810791016,40.785301208496094,40.77215576171875,40.73340606689453,40.72909164428711,40.790351867675774,40.75816345214844,40.75542831420898,40.759613037109375,40.7446403503418,40.774028778076165,40.74638366699219,40.7152099609375,40.79330825805664,40.76351165771485,40.71578979492188,40.730594635009766,40.75276947021485,40.74660873413086,40.755725860595696,40.72389602661133,40.7464599609375,40.72296524047852,40.711273193359375,40.740264892578125,40.7133903503418,40.760963439941406,40.75766754150391,40.75098419189453,40.75508880615234,40.771766662597656,40.78485870361328,40.74100875854492,40.730010986328125,40.765640258789055,40.767120361328125,40.75265884399414,40.784400939941406,40.72898864746094,40.79521179199219,40.776042938232415,40.64469146728516,40.73111343383789,40.739891052246094,40.70663070678711,40.726726531982415,40.741565704345696,40.752811431884766,40.75893020629882,40.7596549987793,40.762401580810554,40.77669143676758,40.73746109008789,40.76033782958984,40.750591278076165,40.74824905395508,40.719993591308594,40.73286056518555,40.748241424560554,40.778587341308594,40.747650146484375,40.7318115234375,40.78296661376953,40.75055313110352,40.77458953857422,40.769779205322266,40.7619514465332,40.7457160949707,40.755950927734375,40.76438903808594,40.77969741821289,40.75584030151367,40.77640151977539,40.785541534423835,40.73815155029297,40.77366256713867,40.77041244506836,40.73389434814453,40.764678955078125,40.64264297485352,40.72468948364258,40.75102996826172,40.7417221069336,40.74003601074219,40.76722717285156,40.716991424560554,40.78342819213867,40.7842903137207,40.754859924316406,40.74430084228516,40.76622009277344,40.75494766235352,40.73622894287109,40.7783088684082,40.76171875,40.773262023925774,40.77532958984375,40.742671966552734,40.77312469482422,40.77063751220703,40.7181396484375,40.753765106201165,40.76463317871094,40.77021026611328,40.733985900878906,40.64699172973633,40.72029113769531,40.77608871459961,40.73360824584961,40.70621109008789,40.760372161865234,40.75006103515625,40.7558708190918,40.721309661865234,40.71538925170898,40.765449523925774,40.75085067749024,40.78924179077149,40.76710891723633,40.766639709472656,40.74443817138672,40.79832077026367,40.756393432617195,40.75114440917969,40.76482009887695,40.79532241821289,40.74234008789063,40.7424430847168,40.78874588012695,40.75398635864258,40.79092025756836,40.72100830078125,40.71598815917969,40.728702545166016,40.7527732849121,40.75879287719727,40.77823257446289,40.715728759765625,40.64542388916016,40.77602767944336,40.74916458129882,40.7646484375,40.74284362792969,40.76208114624024,40.742141723632805,40.73646545410156,40.7458381652832,40.76546096801758,40.750038146972656,40.76049041748047,40.75541305541992,40.73128128051758,40.74324035644531,40.7586784362793,40.7485237121582,40.755279541015625,40.78524017333984,40.74169158935546,40.73493576049805,40.719993591308594,40.760417938232415,40.75755310058594,40.7418098449707,40.78483581542969,40.7999 ...

# %% [markdown]
# ### Chart-6
#
# *   daytime vs taxi service frequency

# %%
# converting time to datetime format
data['pickup_datetime'] = pd.to_datetime(data['pickup_datetime'])
data['dropoff_datetime'] = pd.to_datetime(data['dropoff_datetime'])

# %%
# taxi trip frequency across months
ax=sns.countplot(x=data['pickup_datetime'].dt.month)
ax.set_xticks([0, 1, 2, 3, 4, 5, 6])  # set 4 tick locations
ax.set_xticklabels(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul"])
plt.xlabel('Pick Up Time')
plt.ylabel('No. of Trips')
plt.title('Trips Over Months')
plt.show()

# %% [markdown]
# Datetime
# 1. This data is for year 2016 olny.
# 2. It has just month from Jan to Jul

# %% [markdown]
# ### Chart-7

# %%
# bar plot
sns.countplot(x=data['pickup_datetime'].dt.hour )
plt.xlabel('Pick Up Time')
plt.ylabel('No. of Trips')
plt.title('Trips Over a Day')
plt.show()

# %% [markdown]
# 1. mostly people travel in night 6pm to 12pm.
# 2. Traffic is just constant from 9am to 5pm. It may be because of office hours.

# %% [markdown]
# ### Chart-8

# %%
# density plot
data['trip_duration'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# this column has outliers that is why it's distribution is not clear. Therefore we will plot it after outlier removal

# %% [markdown]
# ### Chart-9

# %%
# converting time to datetime format
data['pickup_datetime'] = pd.to_datetime(data['pickup_datetime'])
data['dropoff_datetime'] = pd.to_datetime(data['dropoff_datetime'])

# %%
# double bar plot
sns.countplot(x=data['pickup_datetime'].dt.hour, hue=data['vendor_id'] )
plt.xlabel('Pick Up Time')
plt.ylabel('No. of Trips')
plt.title('Trips Over a Day')
plt.show()

# %% [markdown]
# Vendor 1 is on top in carrying single passengers whereas vendor 2 is on top in carrying more than 2 passengers. It may be because passengers prefer share taxi trip from vendor 2

# %% [markdown]
# ### Chart-10

# %%
# correlation matrix
plt.figure(figsize=(12,8))
corr=data.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##3.Feature Enginneering

# %%
# loading data again
data=pd.read_csv('/content/drive/MyDrive/AlmaBetter/Captstone project/Regression/NYC Taxi Data.csv')

# %%
# creating copy of data
df=data.copy()

df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
df['dropoff_datetime'] = pd.to_datetime(df['dropoff_datetime'])
df['store_and_fwd_flag']=df['store_and_fwd_flag'].apply(lambda x: 0 if x=='N' else 1)

# creating  hour and month column
df['hour']=df['pickup_datetime'].dt.hour
df['month']=df['pickup_datetime'].dt.month

#Droping unnecessary columns
df.drop(['dropoff_datetime','pickup_datetime','id'], axis=1, inplace=True)

# %%
# column details
df.columns
# Out:
# Index(['vendor_id', 'passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
#        'trip_duration', 'hour', 'month'],
#       dtype='object')

# %% [markdown]
# ##4.Outlier treatment

# %%
df=data.copy()
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
df['dropoff_datetime'] = pd.to_datetime(df['dropoff_datetime'])


# creating  hour and month column
df['hour']=df['pickup_datetime'].dt.hour
df['month']=df['pickup_datetime'].dt.month

#Droping unnecessary columns
df.drop(['dropoff_datetime','pickup_datetime','id'], axis=1, inplace=True)

# %%
# numeric columns for box plot
numeric_columns=[c for c in df.columns if c not in ['vendor_id', 'passenger_count', 'store_and_fwd_flag']]
numeric_columns
# Out:
# ['pickup_longitude',
#  'pickup_latitude',
#  'dropoff_longitude',
#  'dropoff_latitude',
#  'trip_duration',
#  'hour',
#  'month']

# %% [markdown]
# ### Chart-11

# %%
# box plots of all features
plt.figure(figsize=(25,10))
for i, columns in enumerate(numeric_columns):
  plt.subplot(2,4, i+1)
  df[columns].plot(kind='box')
print(f"before {df.shape}")
# Out:
# before (1458644, 10)

# %% [markdown]
# ### Chart-12

# %%
# distribution plots for all numeric features
plt.figure(figsize=(20,10))
for i, columns in enumerate(numeric_columns):
  plt.subplot(2,4, i+1)
  df[columns].plot(kind='hist')
  plt.title(columns)
print(f"before {df.shape}")
# Out:
# before (1458644, 10)

# %% [markdown]
# ### Chart-13

# %%
# removing outliers using IQR method
for i, column in enumerate(numeric_columns):
  IQR=df[column].quantile(0.75)-df[column].quantile(0.25)
  UL=df[column].quantile(0.75)+IQR*1.5
  LL=df[column].quantile(0.25)-IQR*1.5
  df.drop(df[(df[column]>=UL)|(df[column]<=LL)].index, inplace=True)

# %%
# removing outliers using Standard deviation method

for i, column in enumerate(numeric_columns):
  mean = np.mean(df[column])
  std = np.std(df[column])
  df[f'{column}+_cleaned'] = df[column].apply(lambda x: (x-mean)/std)
  df.drop(index=df.loc[(df[f'{column}+_cleaned']<-2.5) | (2.5<df[f'{column}+_cleaned'])].index, inplace=True)
  df.drop(columns=[f'{column}+_cleaned'], inplace=True)
df.shape[0]
# Out:
# 1161647

# %%
# distribution plots for all numeric features
plt.figure(figsize=(20,10))
for i, columns in enumerate(numeric_columns):
  plt.subplot(2,4, i+1)
  df[columns].plot(kind='hist')
  plt.title(columns)
print(f"after {df.shape}")
# Out:
# before (1161088, 10)

# %% [markdown]
# ### Chart-14

# %%
# box plots of all features
plt.figure(figsize=(20,10))
for i, columns in enumerate(numeric_columns):
  plt.subplot(2,4, i+1)
  df[columns].plot(kind='box')
print(f"after {df.shape}")
# Out:
# before (1161647, 10)

# %% [markdown]
# ### Chart-15

# %%
# trip duration distribution
df['trip_duration'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Above density plot shows that it is slightly rightly skewd distribution.

# %% [markdown]
# ##5.Feature Encoding

# %%
# feature encoding 0 for Y and 1 for N
df['store_and_fwd_flag']=df['store_and_fwd_flag'].apply(lambda x: 0 if x=='N' else 1)

# %% [markdown]
# ##6.Model building

# %% [markdown]
# ### Model trained
# 1. Linear Regression
# 2. KNN
# 3. Decision Tree
# 4. SVM
# 5. Random forest

# %% [markdown]
# As dataset is very big so, we will take sample of it to check which algorithms works best then  finetune and finally train with entire dataset.

# %%
def my_train_test_split(df, scaler_='StandardScaler'):

  ''' return scaled train and test dataset from the given dataset'''

  df=df.copy()
  df.sample(10000)
  y=df['trip_duration']
  X=df[[c for c in df.columns.tolist() if c!='trip_duration']]
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
  if scaler_=='MinMax':
    scaler = StandardScaler()
    X_train=scaler.fit_transform(X_train)
    X_test=scaler.transform(X_test)
  else:
    scaler = StandardScaler()
    X_train=scaler.fit_transform(X_train)
    X_test=scaler.transform(X_test)
  return X_train, X_test, y_train, y_test

# def performance(X_train, X_test, y_train, y_test):
#     mse_train=mean_squared_error(y_train, model.predict(X_train))
#     mse_test=mean_squared_error(y_test, model.predict(X_test))
#     r2_train=r2_score(y_train, model.predict(X_train))
#     r2_test=r2_score(y_test, model.predict(X_test))  


#     print(f"RMSE of train dataset", mse_train)
#     print(f"RMSE of test dataset", mse_test)
#     print(f"RMSE of train dataset", r2_test)
#     print(f"RMSE of test dataset", r2_train)

def model(algo):

  ''' Train given model with default hayperparameters '''

  X_train, X_test, y_train, y_test=my_train_test_split(df)
  if algo=='Linear Regression':
    model = LinearRegression()
    model.fit(X_train, y_train)
  elif algo=='Decision Tree':
    model = DecisionTreeRegressor()
    model.fit(X_train, y_train)

  elif algo=='KNN':
    model = KNeighborsRegressor()
    model.fit(X_train, y_train)

  elif algo=='SVR':
    model = SVR()
    model.fit(X_train, y_train)

  else:
    model = RandomForestRegressor()
    model.fit(X_train, y_train)
  

  mse_train=mean_squared_error(y_train, model.predict(X_train), squared=False)
  mse_test=mean_squared_error(y_test, model.predict(X_test), squared=False)
  r2_train=r2_score(y_train, model.predict(X_train))
  r2_test=r2_score(y_test, model.predict(X_test))  


  print(f"RMSE of train dataset", mse_train)
  print(f"RMSE of test dataset", mse_test)
  print(f"R2_score of test dataset", r2_test)
  print(f"R2_score of train dataset", r2_train)

# %%
# Creating List of models
model_name=['Linear Regression', 'Decision Tree', 'KNN', 'SVM', 'Random Forest']

# %%
# Training all model using for loop
for algorithm in model_name:
  start_time=datetime.now()
  print(algorithm)
  model(algorithm)
  print(f"Time taken: {datetime.now()-start_time}3")
# Out:
# Linear Regression
# RMSE of train dataset 342.2824278660138
# RMSE of test dataset 342.0022079978817
# R2_score of train dataset 0.017422770379914798
# R2_score of test dataset 0.016886899006359868
# Time taken: 0:00:01.2146253
# Decision Tree
# RMSE of train dataset 1.0249614141017533
# RMSE of test dataset 276.831122727083
# R2_score of train dataset 0.35621818664865823
# R2_score of test dataset 0.9999911844521276
# Time taken: 0:00:16.2473763
# KNN
# RMSE of train dataset 180.47758557822996
# RMSE of test dataset 221.89064342901773
# R2_score of train dataset 0.5863939766997097
# R2_score of test dataset 0.7266740787378236
# Time taken: 0:27:07.4205603
# SVM
# RMSE of train dataset 72.85696254203434
# RMSE of test dataset 194.62522682628347
# R2_score of train dataset 0.6817948976784651
# R2_score of test dataset 0.9554573143942908
# Time taken: 0:19:47.0440043
# Random Forest
# RMSE of train dataset 72.84534035064429
# RMSE of test dataset 194.65115478318754
# R2_score of train dataset 0.6817101095153524
# R2_score of test dataset 0.9554715242188143
# Time taken: 0:19:59.2932933

# %% [markdown]
# ### Random Forest without log transformation

# %%
from sklearn.preprocessing import MinMaxScaler
# Default model
# without log transformation

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
df=df.sample(10000, random_state=42)

y=df['trip_duration']

# y=np.log(y)
X=df[[c for c in df.columns.tolist() if c!='trip_duration']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

start=datetime.now()
print('.........Training.......\n')
model = RandomForestRegressor()
model.fit(X_train, y_train)

print('Training time', datetime.now()-start)

print('\n')

mse_train=mean_squared_error(y_train, model.predict(X_train), squared=False)
mse_test=mean_squared_error(y_test, model.predict(X_test), squared=False)
r2_train=r2_score(y_train, model.predict(X_train))
r2_test=r2_score(y_test, model.predict(X_test))  


print(f"RMSE of train dataset", mse_train)
print(f"RMSE of test dataset", mse_test)
print(f"R2_score of train dataset", r2_train)
print(f"R2_score of test dataset", r2_test)
# Out:
# .........Training.......
#
# Training time 0:00:08.472304
#
#
# RMSE of train dataset 86.59787801219083
# RMSE of test dataset 225.74685838101936
# R2_score of train dataset 0.9386335125701347
# R2_score of test dataset 0.5736003760057313

# %% [markdown]
# ### Random Forest with log transformation

# %%
# Default model
# with log transformation

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
df=df.sample(10000, random_state=42)

y=df['trip_duration']

y=np.log(y)
X=df[[c for c in df.columns.tolist() if c!='trip_duration']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

start=datetime.now()
print('.........Training.......\n')
model = RandomForestRegressor()
model.fit(X_train, y_train)

print('Training time', datetime.now()-start)

print('\n')

mse_train=mean_squared_error(y_train, model.predict(X_train), squared=False)
mse_test=mean_squared_error(y_test, model.predict(X_test), squared=False)
r2_train=r2_score(y_train, model.predict(X_train))
r2_test=r2_score(y_test, model.predict(X_test))  


print(f"RMSE of train dataset", mse_train)
print(f"RMSE of test dataset", mse_test)
print(f"R2_score of train dataset", r2_train)
print(f"R2_score of test dataset", r2_test)
# Out:
# .........Training.......
#
# Training time 0:00:08.244061
#
#
# RMSE of train dataset 0.16996225102870763
# RMSE of test dataset 0.466695219273431
# R2_score of train dataset 0.9319113690093473
# R2_score of test dataset 0.5162214971867402

# %% [markdown]
# we tried training model on transformed output an dfound that result witout log transformation is better.

# %% [markdown]
# ##6.Hyperparameter tuning

# %% [markdown]
# ### Random Forest

# %%
# Hyperparameter tuning
n_estimators = [20,50,80]+[int(x) for x in np.linspace(start = 100, stop = 1000, num = 10)]
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
max_features = [2,3,4,5,6,7,8,9]
max_depth = [2,5,10,20,30,40,50,80]

# %%
# Creating hyperparameters grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf }

# %%
# Default model
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
df=df.sample(10000, random_state=42)

y=df['trip_duration']

# y=np.log(y)
X=df[[c for c in df.columns.tolist() if c!='trip_duration']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

rf=RandomForestRegressor()
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,  cv = 3, verbose=2, random_state=42)
# Fit
rf_random.fit(X_train, y_train)

# start=datetime.now()
# print('.........Training.......\n')
# model = RandomForestRegressor()
# model.fit(X_train, y_train)

# print('Training time', datetime.now()-start)

# print('\n')

# mse_train=mean_squared_error(y_train, model.predict(X_train), squared=False)
# mse_test=mean_squared_error(y_test, model.predict(X_test), squared=False)
# r2_train=r2_score(y_train, model.predict(X_train))
# r2_test=r2_score(y_test, model.predict(X_test))  


# print(f"RMSE of train dataset", mse_train)
# print(f"RMSE of test dataset", mse_test)
# print(f"R2_score of train dataset", r2_train)
# print(f"R2_score of test dataset", r2_test)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] END max_depth=80, max_features=8, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.8s
# [CV] END max_depth=80, max_features=8, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.9s
# [CV] END max_depth=80, max_features=8, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.3s
# [CV] END max_depth=2, max_features=9, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=   0.4s
# [CV] END max_depth=2, max_features=9, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=   0.4s
# [CV] END max_depth=2, max_features=9, min_samples_leaf=2, min_samples_split=2, n_estimators=80; total time=   0.4s
# [CV] END max_depth=40, max_features=8, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  16.9s
# [CV] END max_depth=40, max_features=8, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  19.0s
# [CV] END max_depth=40, max_features=8, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  17.5s
# [CV] END max_depth=40, max_features=6, min_samples_leaf=4, min_samples_split=2, n_estimators=20; total time=   0.3s
# [CV] END max_depth=40, max_features=6, min_samples_leaf=4, min_samples_split=2, n_estimators=20; total time=   0.3s
# [CV] END max_depth=40, max_features=6, min_samples_leaf=4, min_samples_split=2, n_estimators=20; total time=   0.3s
# [CV] END max_depth=40, max_features=6, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=40, max_features=6, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=40, max_features=6, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.9s
# [CV] END max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   0.6s
# [CV] END max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   0.6s
# [CV] END max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   0.6s
# [CV] END max_depth=20, max_features=4, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=  13.0s
# [CV] END max_depth=20, max_features=4, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=  12.8s
# [CV] END max_depth=20, max_features=4, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=  12.3s
# [CV] END max_depth=50, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=50, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=50, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=50, max_features=7, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=  22.6s
# [CV] END max_depth=50, max_features=7, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=  22.6s
# [CV] END max_depth=50, max_features=7, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=  21.0s
# [CV] END max_depth=2, max_features=5, min_samples_leaf=4, min_samples_split=10, n_estimators=900; total time=   4.4s
# [CV] END max_depth=2, max_features=5, min_samples_leaf=4, min_samples_split=10, n_estimators=900; total time=   3.6s
# [CV] END max_depth=2, max_features=5, min_samples_leaf=4, min_samples_split=10, n_estimators=900; total time=   3.2s
# RandomizedSearchCV(cv=3, estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [2, 5, 10, 20, 30, 40, 50,
#                                                       80],
#                                         'max_features': [2, 3, 4, 5, 6, 7, 8,
#                                                          9],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [20, 50, 80, 100, 200,
#                                                          300, 400, 500, 600,
#                                                          700, 800, 900, 1000]},
#                    random_state=42, verbose=2)

# %%
#best estimators
rf_random.best_estimator_
# Out:
# RandomForestRegressor(max_depth=40, max_features=6, min_samples_leaf=2,
#                       n_estimators=200)

# %%
# Default model
# with log transformation

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split


y=df['trip_duration']

# y=np.log(y)
X=df[[c for c in df.columns.tolist() if c!='trip_duration']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

start=datetime.now()
print('.........Training.......\n')
model = RandomForestRegressor(max_depth=40, max_features=6, min_samples_leaf=2,
                      n_estimators=200)
model.fit(X_train, y_train)

print('Training time', datetime.now()-start)

print('\n')

mse_train=mean_squared_error(y_train, model.predict(X_train), squared=False)
mse_test=mean_squared_error(y_test, model.predict(X_test), squared=False)
r2_train=r2_score(y_train, model.predict(X_train))
r2_test=r2_score(y_test, model.predict(X_test))  


print(f"RMSE of train dataset", mse_train)
print(f"RMSE of test dataset", mse_test)
print(f"R2_score of train dataset", r2_train)
print(f"R2_score of test dataset", r2_test)
# Out:
# .........Training.......
#
# Training time 0:20:22.419607
#
#
# RMSE of train dataset 94.2172457133349
# RMSE of test dataset 191.65423326336483
# R2_score of train dataset 0.9255104956921231
# R2_score of test dataset 0.6914356783390676

# %% [markdown]
# ##7.Conclusions
# •	Keeping in mind the concept of “Garbage In, Garbage Out”, It is utmost important to clean and prepare the dataset well before model training.
#
# •	We checked for null values and plotted different charts to get insights that:
#
#     •	Vendor 2 has got 7% more taxi trips than vendor 1.
#     •	Most taxi trips carry one passengers and they rarely carry zero passengers or more than six.
#     •	Most of the trip records are held in vehicle memory.
#     •	Most of the taxi trips are in the middle of the city.
#     •	Mostly people travel in night 6pm to 12pm.
# •	Two new features, hours and days of week are created in feature engineering
#
# •	Five models are trained, out of which random forest and SVM outperformed all on the basis of r2 score of each model. Finally random forest is selected because it is fast.
#
# •	RandomisedSearchCV with CV=3 is used over 7488 random forest models.
#
# •	We tried different algorithm to reduce overfitting but with that model also loses significant r2 score.
#
# •	Finally, we developed a Random Forest Regressor with r2 score of 0.7
